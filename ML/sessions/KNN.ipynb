# %% [markdown]
# ### Import libraries

# %%
import numpy as np
from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt
from tqdm import tqdm
import pandas as pd
import seaborn as sns

# %% [markdown]
# ### Generate data

# %%
# Generate a synthetic dataset with two features for binary classification
X, y = make_classification(n_samples=1000, n_features=2, n_informative=2, n_redundant=0, n_classes=2, random_state=3)

# %%
df= pd.DataFrame({"x1": X[:,0], "x2": X[:, 1], 'y':y})

# %%
sns.scatterplot(x= 'x1', y='x2', data= df, hue= 'y')
# Out:
# <AxesSubplot:xlabel='x1', ylabel='x2'>

# %%
X[:10]
# Out:
# array([[-0.01780924,  2.0025585 ],
#        [-0.63239137,  1.39801172],
#        [ 1.24193177,  0.40239896],
#        [ 1.63439594, -1.32019236],
#        [ 1.25878166, -1.57903609],
#        [ 0.64697248,  1.40820621],
#        [ 1.54266874, -0.30566859],
#        [-1.58852064, -0.37366133],
#        [-0.43382856,  1.49907951],
#        [-1.75024394,  0.35921552]])

# %%
y[:10]
# Out:
# array([1, 1, 1, 0, 0, 1, 1, 0, 1, 1])

# %% [markdown]
# ### Split data

# %%
# Split the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %% [markdown]
# ### Create a KNN model and fit it

# %%
# Initialize the KNN classifier with k=3
knn = KNeighborsClassifier(n_neighbors=3)

# Fit the model to the training data
knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %% [markdown]
# ### Make predictions on test set

# %%
# Make predictions on the test data
y_pred = knn.predict(X_test)

# %% [markdown]
# ### Evaluate teh model

# %%
# Calculate the accuracy of the model
accuracy = accuracy_score(y_test, y_pred)
print(f'Accuracy: {accuracy * 100:.2f}%')
# Out:
# Accuracy: 98.33%

# %% [markdown]
# ### Visualize <strong>K</strong> choice effect

# %% [markdown]
# #### K= 3

# %%
# Visualize the decision boundary
x_min, x_max = X[:, 0].min() - 1, X[:, 0].max() + 1
y_min, y_max = X[:, 1].min() - 1, X[:, 1].max() + 1
xx, yy = np.meshgrid(np.arange(x_min, x_max, 0.01), np.arange(y_min, y_max, 0.01))
Z = knn.predict(np.c_[xx.ravel(), yy.ravel()])
Z = Z.reshape(xx.shape)

plt.contourf(xx, yy, Z, alpha=0.4)
plt.scatter(X[:, 0], X[:, 1], c=y, marker='o', edgecolors='k')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.title('KNN Classification (Binary)')

plt.show()

# %% [markdown]
# #### K=5

# %%
# Initialize the KNN classifier with k=5
knn = KNeighborsClassifier(n_neighbors=5)

# Fit the model to the training data
knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
# Make predictions on the test data
y_pred = knn.predict(X_test)

# %%
# Calculate the accuracy of the model
accuracy = accuracy_score(y_test, y_pred)
print(f'Accuracy: {accuracy * 100:.2f}%')
# Out:
# Accuracy: 97.67%

# %%
# Visualize the decision boundary
x_min, x_max = X[:, 0].min() - 1, X[:, 0].max() + 1
y_min, y_max = X[:, 1].min() - 1, X[:, 1].max() + 1
xx, yy = np.meshgrid(np.arange(x_min, x_max, 0.01), np.arange(y_min, y_max, 0.01))
Z = knn.predict(np.c_[xx.ravel(), yy.ravel()])
Z = Z.reshape(xx.shape)

plt.contourf(xx, yy, Z, alpha=0.4)
plt.scatter(X[:, 0], X[:, 1], c=y, marker='o', edgecolors='k')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.title('KNN Classification (Binary)')

plt.show()

# %% [markdown]
# #### K=11

# %%
# Initialize the KNN classifier with k=11
knn = KNeighborsClassifier(n_neighbors=11)

# Fit the model to the training data
knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=11)

# %%
# Make predictions on the test data
y_pred = knn.predict(X_test)

# %%
# Calculate the accuracy of the model
accuracy = accuracy_score(y_test, y_pred)
print(f'Accuracy: {accuracy * 100:.2f}%')
# Out:
# Accuracy: 96.67%

# %%
# Visualize the decision boundary
x_min, x_max = X[:, 0].min() - 1, X[:, 0].max() + 1
y_min, y_max = X[:, 1].min() - 1, X[:, 1].max() + 1
xx, yy = np.meshgrid(np.arange(x_min, x_max, 0.01), np.arange(y_min, y_max, 0.01))
Z = knn.predict(np.c_[xx.ravel(), yy.ravel()])
Z = Z.reshape(xx.shape)

plt.contourf(xx, yy, Z, alpha=0.4)
plt.scatter(X[:, 0], X[:, 1], c=y, marker='o', edgecolors='k')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.title('KNN Classification (Binary)')

plt.show()

# %% [markdown]
# #### K= full training length

# %%
# Initialize the KNN classifier with k= full training length
knn = KNeighborsClassifier(n_neighbors=len(X_train))

# Fit the model to the training data
knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=700)

# %%
# Make predictions on the test data
y_pred = knn.predict(X_test)

# %%
# Calculate the accuracy of the model
accuracy = accuracy_score(y_test, y_pred)
print(f'Accuracy: {accuracy * 100:.2f}%')
# Out:
# Accuracy: 48.33%

# %%
# Visualize the decision boundary
x_min, x_max = X[:, 0].min() - 1, X[:, 0].max() + 1
y_min, y_max = X[:, 1].min() - 1, X[:, 1].max() + 1
xx, yy = np.meshgrid(np.arange(x_min, x_max, 0.01), np.arange(y_min, y_max, 0.01))
Z = knn.predict(np.c_[xx.ravel(), yy.ravel()])
Z = Z.reshape(xx.shape)

plt.contourf(xx, yy, Z, alpha=0.4)
plt.scatter(X[:, 0], X[:, 1], c=y, marker='o', edgecolors='k')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.title('KNN Classification (Binary)')

plt.show()

# %% [markdown]
# ### Training Error Rate & Validation Error Rate

# %%
# Lists to store error rates for train and validation sets
train_errors = []
val_errors = []
knn = KNeighborsClassifier(n_neighbors=3)

for k in tqdm(range(1, 20)):
    knn.n_neighbors = k
    knn.fit(X_train, y_train)
    y_train_pred = knn.predict(X_train)
    y_val_pred = knn.predict(X_test)
    train_errors.append(1 - accuracy_score(y_train, y_train_pred))
    val_errors.append(1 - accuracy_score(y_test, y_val_pred))
# Out:
# 100%|██████████| 19/19 [00:00<00:00, 22.84it/s]

# %%
plt.figure(figsize=(12, 4))

# Plot the training error rate curve
plt.subplot(1, 2, 1)
plt.plot(range(1, len(train_errors)+1), train_errors, marker='o')
plt.axhline(y=train_errors[3], c='red')
plt.axvline(x=4, c='red')
plt.xlabel('Number of Neighbors (k)')
plt.ylabel('Training Error Rate')
plt.title('KNN Training Error Rate')

# Plot the validation error rate curve
plt.subplot(1, 2, 2)
plt.plot(range(1, len(val_errors)+1), val_errors, marker='o')
plt.axhline(y=val_errors[3], c='red')
plt.axvline(x=4, c='red')
plt.xlabel('Number of Neighbors (k)')
plt.ylabel('Validation Error Rate')
plt.title('KNN Validation Error Rate')

plt.tight_layout()

# %% [markdown]
# ### Changing the metric

# %% [markdown]
# ### Create a KNN model and fit it

# %%
# Initialize the KNN classifier with k=3
knn = KNeighborsClassifier(n_neighbors=3, metric='cosine')

# Fit the model to the training data
knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(metric='cosine', n_neighbors=3)

# %% [markdown]
# ### Make predections on test set

# %%
# Make predictions on the test data
y_pred = knn.predict(X_test)

# %% [markdown]
# ### Evaluate teh model

# %%
# Calculate the accuracy of the model
accuracy = accuracy_score(y_test, y_pred)
print(f'Accuracy: {accuracy * 100:.2f}%')
# Out:
# Accuracy: 88.00%

# %% [markdown]
# ### Visualize <strong>K</strong> choice effect

# %% [markdown]
# #### K= 3

# %%
# Visualize the decision boundary
x_min, x_max = X[:, 0].min() - 1, X[:, 0].max() + 1
y_min, y_max = X[:, 1].min() - 1, X[:, 1].max() + 1
xx, yy = np.meshgrid(np.arange(x_min, x_max, 0.01), np.arange(y_min, y_max, 0.01))
Z = knn.predict(np.c_[xx.ravel(), yy.ravel()])
Z = Z.reshape(xx.shape)

plt.contourf(xx, yy, Z, alpha=0.4)
plt.scatter(X[:, 0], X[:, 1], c=y, marker='o', edgecolors='k')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.title('KNN Classification (Binary)')

plt.show()

# %% [markdown]
# #### K=5

# %%
# Initialize the KNN classifier with k=5
knn = KNeighborsClassifier(n_neighbors=5, metric='cosine')

# Fit the model to the training data
knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(metric='cosine')

# %%
# Make predictions on the test data
y_pred = knn.predict(X_test)

# %%
# Calculate the accuracy of the model
accuracy = accuracy_score(y_test, y_pred)
print(f'Accuracy: {accuracy * 100:.2f}%')
# Out:
# Accuracy: 89.33%

# %%
# Visualize the decision boundary
x_min, x_max = X[:, 0].min() - 1, X[:, 0].max() + 1
y_min, y_max = X[:, 1].min() - 1, X[:, 1].max() + 1
xx, yy = np.meshgrid(np.arange(x_min, x_max, 0.01), np.arange(y_min, y_max, 0.01))
Z = knn.predict(np.c_[xx.ravel(), yy.ravel()])
Z = Z.reshape(xx.shape)

plt.contourf(xx, yy, Z, alpha=0.4)
plt.scatter(X[:, 0], X[:, 1], c=y, marker='o', edgecolors='k')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.title('KNN Classification (Binary)')

plt.show()

# %% [markdown]
# #### K=11

# %%
# Initialize the KNN classifier with k=11
knn = KNeighborsClassifier(n_neighbors=11, metric='cosine')

# Fit the model to the training data
knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(metric='cosine', n_neighbors=11)

# %%
# Make predictions on the test data
y_pred = knn.predict(X_test)

# %%
# Calculate the accuracy of the model
accuracy = accuracy_score(y_test, y_pred)
print(f'Accuracy: {accuracy * 100:.2f}%')
# Out:
# Accuracy: 89.67%

# %%
# Visualize the decision boundary
x_min, x_max = X[:, 0].min() - 1, X[:, 0].max() + 1
y_min, y_max = X[:, 1].min() - 1, X[:, 1].max() + 1
xx, yy = np.meshgrid(np.arange(x_min, x_max, 0.01), np.arange(y_min, y_max, 0.01))
Z = knn.predict(np.c_[xx.ravel(), yy.ravel()])
Z = Z.reshape(xx.shape)

plt.contourf(xx, yy, Z, alpha=0.4)
plt.scatter(X[:, 0], X[:, 1], c=y, marker='o', edgecolors='k')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.title('KNN Classification (Binary)')

plt.show()

# %% [markdown]
# #### K= full training length

# %%
# Initialize the KNN classifier with k= full training length
knn = KNeighborsClassifier(n_neighbors=len(X_train), metric='cosine')

# Fit the model to the training data
knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(metric='cosine', n_neighbors=700)

# %%
# Make predictions on the test data
y_pred = knn.predict(X_test)

# %%
# Calculate the accuracy of the model
accuracy = accuracy_score(y_test, y_pred)
print(f'Accuracy: {accuracy * 100:.2f}%')
# Out:
# Accuracy: 48.33%

# %%
# Visualize the decision boundary
x_min, x_max = X[:, 0].min() - 1, X[:, 0].max() + 1
y_min, y_max = X[:, 1].min() - 1, X[:, 1].max() + 1
xx, yy = np.meshgrid(np.arange(x_min, x_max, 0.01), np.arange(y_min, y_max, 0.01))
Z = knn.predict(np.c_[xx.ravel(), yy.ravel()])
Z = Z.reshape(xx.shape)

plt.contourf(xx, yy, Z, alpha=0.4)
plt.scatter(X[:, 0], X[:, 1], c=y, marker='o', edgecolors='k')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.title('KNN Classification (Binary)')

plt.show()

# %% [markdown]
# ### Training Error Rate & Validation Error Rate

# %%
# Lists to store error rates for train and validation sets
train_errors = []
val_errors = []
knn = KNeighborsClassifier(n_neighbors=3, metric='cosine')

for k in tqdm(range(1, 20)):
    knn.n_neighbors = k
    knn.fit(X_train, y_train)
    y_train_pred = knn.predict(X_train)
    y_val_pred = knn.predict(X_test)
    train_errors.append(1 - accuracy_score(y_train, y_train_pred))
    val_errors.append(1 - accuracy_score(y_test, y_val_pred))
# Out:
# 100%|██████████| 19/19 [00:00<00:00, 20.19it/s]

# %%
plt.figure(figsize=(12, 4))

# Plot the training error rate curve
plt.subplot(1, 2, 1)
plt.plot(range(1, len(train_errors)+1), train_errors, marker='o')
plt.xlabel('Number of Neighbors (k)')
plt.ylabel('Training Error Rate')
plt.title('KNN Training Error Rate')

# Plot the validation error rate curve
plt.subplot(1, 2, 2)
plt.plot(range(1, len(val_errors)+1), val_errors, marker='o')
plt.xlabel('Number of Neighbors (k)')
plt.ylabel('Validation Error Rate')
plt.title('KNN Validation Error Rate')

plt.tight_layout()
