# %% [markdown]
# [datasete here:](https://drive.google.com/file/d/1lp3A2Iet3QGXxRIrsh5q9YlZRmKgjOl7/view?usp=sharing)

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import scipy as sp

# %%
df = pd.read_csv('Covid Data.csv')
df.head()
# Out:
#    USMER  MEDICAL_UNIT  SEX  PATIENT_TYPE   DATE_DIED  INTUBED  PNEUMONIA  \
# 0      2             1    1             1  03/05/2020       97          1
# 1      2             1    2             1  03/06/2020       97          1
# 2      2             1    2             2  09/06/2020        1          2
# 3      2             1    1             1  12/06/2020       97          2
# 4      2             1    2             1  21/06/2020       97          2
#
#    AGE  PREGNANT  DIABETES  ...  ASTHMA  INMSUPR  HIPERTENSION  OTHER_DISEASE  \
# 0   65         2         2  ...       2        2             1              2
# 1   72        97         2  ...       2        2             1              2
# 2   55        97         1  ...       2        2             2              2
# 3   53         2         2  ...       2        2             2              2
# 4   68        97         1  ...       2        2             1              2
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048575 entries, 0 to 1048574
# Data columns (total 21 columns):
#  #   Column                Non-Null Count    Dtype
# ---  ------                --------------    -----
#  0   USMER                 1048575 non-null  int64
#  1   MEDICAL_UNIT          1048575 non-null  int64
#  2   SEX                   1048575 non-null  int64
#  3   PATIENT_TYPE          1048575 non-null  int64
#  4   DATE_DIED             1048575 non-null  object
#  5   INTUBED               1048575 non-null  int64
#  6   PNEUMONIA             1048575 non-null  int64
#  7   AGE                   1048575 non-null  int64
#  8   PREGNANT              1048575 non-null  int64
#  9   DIABETES              1048575 non-null  int64
#  10  COPD                  1048575 non-null  int64
#  11  ASTHMA                1048575 non-null  int64
#  12  INMSUPR               1048575 non-null  int64
#  13  HIPERTENSION          1048575 non-null  int64
# ...

# %%
df.isnull().sum()
# Out:
# USMER                   0
# MEDICAL_UNIT            0
# SEX                     0
# PATIENT_TYPE            0
# DATE_DIED               0
# INTUBED                 0
# PNEUMONIA               0
# AGE                     0
# PREGNANT                0
# DIABETES                0
# COPD                    0
# ASTHMA                  0
# INMSUPR                 0
# HIPERTENSION            0
# OTHER_DISEASE           0
# CARDIOVASCULAR          0
# OBESITY                 0
# RENAL_CHRONIC           0
# TOBACCO                 0
# CLASIFFICATION_FINAL    0
# ICU                     0
# dtype: int64

# %%
df.describe()
# Out:
#               USMER  MEDICAL_UNIT           SEX  PATIENT_TYPE       INTUBED  \
# count  1.048575e+06  1.048575e+06  1.048575e+06  1.048575e+06  1.048575e+06
# mean   1.632194e+00  8.980565e+00  1.499259e+00  1.190765e+00  7.952288e+01
# std    4.822084e-01  3.723278e+00  4.999997e-01  3.929041e-01  3.686889e+01
# min    1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# 25%    1.000000e+00  4.000000e+00  1.000000e+00  1.000000e+00  9.700000e+01
# 50%    2.000000e+00  1.200000e+01  1.000000e+00  1.000000e+00  9.700000e+01
# 75%    2.000000e+00  1.200000e+01  2.000000e+00  1.000000e+00  9.700000e+01
# max    2.000000e+00  1.300000e+01  2.000000e+00  2.000000e+00  9.900000e+01
#
#           PNEUMONIA           AGE      PREGNANT      DIABETES          COPD  \
# count  1.048575e+06  1.048575e+06  1.048575e+06  1.048575e+06  1.048575e+06
# mean   3.346831e+00  4.179410e+01  4.976558e+01  2.186404e+00  2.260569e+00
# ...

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
def is_dead(date):
    if date == '9999-99-99':
        return 0
    else :
        return 1

# %%
df['dead'] = df['DATE_DIED'].apply(is_dead)

# %%
plt.hist(df['dead']);

# %%
df.groupby('dead')['CLASIFFICATION_FINAL'].value_counts(normalize= True)
# Out:
# dead  CLASIFFICATION_FINAL
# 0     7                       0.499731
#       3                       0.339734
#       6                       0.123998
#       5                       0.025606
#       1                       0.007869
#       4                       0.003061
# 1     3                       0.668426
#       7                       0.177991
#       6                       0.099452
#       2                       0.024057
#       5                       0.015739
#       1                       0.012412
#       4                       0.001924
# Name: proportion, dtype: float64

# %%
plt.hist(df[df['dead']==1]['CLASIFFICATION_FINAL']);

# %%
corr_mat = df.drop(columns ='DATE_DIED').corr()
corr_mat
# Out:
#                          USMER  MEDICAL_UNIT       SEX  PATIENT_TYPE  \
# USMER                 1.000000      0.127927 -0.001126     -0.190570
# MEDICAL_UNIT          0.127927      1.000000  0.001475     -0.205413
# SEX                  -0.001126      0.001475  1.000000      0.089505
# PATIENT_TYPE         -0.190570     -0.205413  0.089505      1.000000
# INTUBED               0.175457      0.205243 -0.089943     -0.976335
# PNEUMONIA            -0.154950     -0.046433 -0.012131      0.022966
# AGE                  -0.045088     -0.082223  0.028367      0.315193
# PREGNANT             -0.001469      0.005300  0.992713      0.088340
# DIABETES              0.014704      0.019523  0.008888      0.008743
# COPD                  0.011030      0.014209  0.009372      0.019548
# ASTHMA                0.010814      0.013312  0.010415      0.023042
# INMSUPR               0.003234      0.011785  0.007999      0.024924
# HIPERTENSION          0.014830      0.020964  0.009257      0.006852
# ...

# %%
sns.heatmap(corr_mat);

# %%
plt.hist(df['AGE']);

# %%
sns.distplot(df['AGE']);

# %%
df['PATIENT_TYPE'].value_counts(normalize = True)
# Out:
# PATIENT_TYPE
# 1    0.809235
# 2    0.190765
# Name: proportion, dtype: float64

# %%
df = df.iloc[:2000]

# %%
values_count = df['PATIENT_TYPE'].value_counts(normalize = True)

# %%
plt.bar(values_count.index,values_count.values);

# %%
plt.pie(values_count);

# %%
sns.countplot(x = 'PATIENT_TYPE', data = df);

# %%
df['year'] = df['DATE_DIED'].apply(lambda x: x[-6:]);

# %%
df['year'] = pd.to_datetime(df['year'], format='mixed', errors='coerce')

df['year'] = df['year'].dt.year

# %%
df[df['dead']==1]['year'].unique()
# Out:
# array([2020.,   nan, 2021.])

# %%
sns.countplot(data = df[df['dead']==1], x = 'year')
# Out:
# <Axes: xlabel='year', ylabel='count'>

# %%
df.groupby('year')['dead'].sum()
# Out:
# year
# 2020.0    1499
# 2021.0       2
# Name: dead, dtype: int64

# %%
df.groupby('SEX')['dead'].sum()
# Out:
# SEX
# 1    539
# 2    963
# Name: dead, dtype: int64

# %%
df['SEX'] = df['SEX'].astype(str)
sns.barplot(data = df, y='CLASIFFICATION_FINAL', x= 'SEX', hue='SEX')
# Out:
# <Axes: xlabel='SEX', ylabel='CLASIFFICATION_FINAL'>
